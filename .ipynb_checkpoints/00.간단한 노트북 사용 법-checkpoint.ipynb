# %%
# 노트북의 셀을 처음부터 순서대로 실행순서를 맞춰야 할 경우 
# Kernel > Restart & Run All 메뉴로 전체 실행 순서를 맞춰주는 것을 추천

a = 10+20
a
# Out:
# 30

# %% [markdown]
# ![Python.svg](attachment:Python.svg)

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6

# %% [markdown]
# | Header 1 | Header 2 | Header 3 |
# |----------|----------|----------|
# | Row 1 Col 1 | Row 1 Col 2 | Row 1 Col 3 |
# | Row 2 Col 1 | Row 2 Col 2 | Row 2 Col 3 |
